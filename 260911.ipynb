# %%
week_string = "2주차"
sum_result = 10 + 20

print(week_string)
print(sum_result)
# Out:
# 2주차
# 30

# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'Paris', 'London', 'Tokyo'],
    'Salary': [70000, 80000, 90000, 75000]
}
df = pd.DataFrame(data)

print("데이터프레임 정보:")
display(df.info())

print("\n데이터프레임의 처음 5행:")
display(df.head())
# Out:
# 데이터프레임 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
#  3   Salary  4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes
# None
# 데이터프레임의 처음 5행:
#       Name  Age      City  Salary
# 0    Alice   25  New York   70000
# 1      Bob   30     Paris   80000
# 2  Charlie   35    London   90000
# 3    David   28     Tokyo   75000

# %%
a="2주차코딩"
print(a)
# Out:
# 2주차코딩

# %%
x=10
y=20
print(x+y)
# Out:
# 30

# %%
print(x+y)
# Out:
# 30

# %%
print(x-y)
# Out:
# -10

# %%
print(x*y)
# Out:
# 200

# %%
print(x/y)
# Out:
# 0.5

# %%
#두자연수 10과 5가 주어진다
#A+B, A-B, A*B, A/B(몫), A%B(나머지)를 출력하는 프로그램을 작성하시오

# %%
A=10
B=5

# %%
print(A+B)
print(A-B)
# Out:
# 15
# 5

# %%
print(A*B)
print(A/B)
print(A%B)
# Out:
# 50
# 2.0
# 0

# %%
#가로12, 세로7 직사각형의 넓이와 둘레를 구하시오

# %%
Q=12
W=7

# %%
print(Q*W)
# Out:
# 84

# %%
print(Q+Q+W+W)
# Out:
# 38

# %%
#국어88, 영어92, 수학 75점인 학생의 과목평균을 구하시오

# %%
국어=88
영어=92
수학=75

# %%
print((국어+영어+수학)/3)
# Out:
# 85.0
